# %% [markdown]
# # Data Cleaning Script — Q-Commerce Raw Files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
INPUT_DIR  = "Existing-Files"
OUTPUT_DIR = "Output-files"

# %% [markdown]
# ## 1. Blinkit

# %%
df_blinkit = pd.read_csv(f"{INPUT_DIR}/blinkit-raw.csv", low_memory=False)

df_blinkit.drop(columns=["Internal SKU"], inplace=True)
df_blinkit = df_blinkit[["item_id", "item_name", "manufacturer_id", "manufacturer_name",
                          "city_id", "city_name", "category", "date", "qty_sold", "mrp"]]
df_blinkit.drop(index=220035, inplace=True)

for col in df_blinkit.select_dtypes(include="object"):
    df_blinkit[col] = df_blinkit[col].str.strip().astype("string")

df_blinkit["item_id"]         = pd.to_numeric(df_blinkit["item_id"])
df_blinkit["manufacturer_id"] = pd.to_numeric(df_blinkit["manufacturer_id"])
df_blinkit["city_id"]         = pd.to_numeric(df_blinkit["city_id"])
df_blinkit["qty_sold"]        = pd.to_numeric(df_blinkit["qty_sold"])
df_blinkit["mrp"]             = pd.to_numeric(df_blinkit["mrp"])
df_blinkit["date"]            = pd.to_datetime(df_blinkit["date"], dayfirst=True)

df_blinkit.drop_duplicates(inplace=True)
df_blinkit.sort_values("date", inplace=True)

# %%
df_blinkit.info()
df_blinkit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230452 entries, 0 to 230452
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   item_id            230452 non-null  Int64
#  1   item_name          230452 non-null  string
#  2   manufacturer_id    230452 non-null  Int64
#  3   manufacturer_name  230452 non-null  string
#  4   city_id            230452 non-null  Int64
#  5   city_name          230452 non-null  string
#  6   category           230452 non-null  string
#  7   date               230452 non-null  datetime64[ns]
#  8   qty_sold           230452 non-null  Int64
#  9   mrp                230452 non-null  Int64
# dtypes: Int64(5), datetime64[ns](1), string(4)
# memory usage: 20.4 MB
#       item_id                         item_name  manufacturer_id  \
# 0    10174324      Chaayos Festive Tea Gift Box             1546
# 122  10074977  Chaayos Adrak Elaichi Tea(Pouch)             1546
# 123  10074977  Chaayos Adrak Elaichi Tea(Pouch)             1546
# 124  10074977  Chaayos Adrak Elaichi Tea(Pouch)             1546
# 125  10074977  Chaayos Adrak Elaichi Tea(Pouch)             1546
#
#                manufacturer_name  city_id    city_name  \
# 0    Sunshine Teahouse Pvt. Ltd.        2       Mumbai
# 122  Sunshine Teahouse Pvt. Ltd.      125    Panchkula
# 123  Sunshine Teahouse Pvt. Ltd.       17       Bhopal
# 124  Sunshine Teahouse Pvt. Ltd.       91  Bahadurgarh
# 125  Sunshine Teahouse Pvt. Ltd.      178       Karnal
#
#                       category       date  qty_sold   mrp
# 0         Cold Drinks & Juices 2024-12-01         3  1647
# 122  Tea, Coffee & Milk Drinks 2024-12-01         4   556
# 123  Tea, Coffee & Milk Drinks 2024-12-01         1   139
# 124  Tea, Coffee & Milk Drinks 2024-12-01         1   139
# 125  Tea, Coffee & Milk Drinks 2024-12-01         1   139

# %%
df_blinkit.to_csv(f"{OUTPUT_DIR}/blinkit_raw.csv", index=False)

# %% [markdown]
# ## 2. Zepto

# %%
df_zepto = pd.read_csv(f"{INPUT_DIR}/zepto-raw.csv", low_memory=False)

df_zepto.drop(df_zepto.iloc[:, 0:10], axis=1, inplace=True)
df_zepto.rename(columns={
    "Date.1"           : "date",
    "SKU Name"         : "sku_name",
    "SKU ID"           : "sku_id",
    "City.1"           : "city",
    "Brand Name"       : "brand_name",
    "Manufacturer ID"  : "manufacture_id",
    "Manufacturer Name": "manufacture_name",
    "SKU Category"     : "sku_category",
    "Quantity"         : "quantity",
    "GMV.1"            : "gmv",
}, inplace=True)

df_zepto["date"] = pd.to_datetime(df_zepto["date"].str.replace("-", "/"), dayfirst=True)

for col in df_zepto.select_dtypes(include="object"):
    df_zepto[col] = df_zepto[col].str.strip().astype("string")

df_zepto.dropna(subset=["quantity"], inplace=True)
df_zepto.sort_values("date", inplace=True)

# %%
df_zepto.info()
df_zepto.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34691 entries, 0 to 35580
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              34691 non-null  datetime64[ns]
#  1   sku_name          34691 non-null  string
#  2   sku_id            34691 non-null  string
#  3   city              34691 non-null  string
#  4   brand_name        34691 non-null  string
#  5   manufacture_id    34691 non-null  string
#  6   manufacture_name  34691 non-null  string
#  7   sku_category      34691 non-null  string
#  8   quantity          34691 non-null  float64
#  9   gmv               34691 non-null  float64
# dtypes: datetime64[ns](1), float64(2), string(7)
# memory usage: 2.9 MB
#           date                                           sku_name  \
# 0   2025-10-01  Chaayos Adrak Elachi Instant Tea Premix - Low ...
# 104 2025-10-01             Chaayos Ginger Cardamom Tea 100.0 GRAM
# 105 2025-10-01             Chaayos Ginger Cardamom Tea 100.0 GRAM
# 106 2025-10-01             Chaayos Ginger Cardamom Tea 100.0 GRAM
# 107 2025-10-01             Chaayos Ginger Cardamom Tea 100.0 GRAM
#
#                                    sku_id        city brand_name  \
# 0    102842f3-8ded-4069-a4d0-1448fc74f924     Chennai    Chaayos
# 104  a7e1f97f-08a3-4543-a82e-ff96af10a513     Kolkata    Chaayos
# 105  a7e1f97f-08a3-4543-a82e-ff96af10a513  Puducherry    Chaayos
# 106  a7e1f97f-08a3-4543-a82e-ff96af10a513  Vijayawada    Chaayos
# 107  a7e1f97f-08a3-4543-a82e-ff96af10a513   Faridabad    Chaayos
#
#                            manufacture_id manufacture_name  \
# 0    ec4e6e5a-d9fe-4edf-8d7c-52d2fa3c8817          Chaayos
# 104  ec4e6e5a-d9fe-4edf-8d7c-52d2fa3c8817          Chaayos
# 105  ec4e6e5a-d9fe-4edf-8d7c-52d2fa3c8817          Chaayos
# 106  ec4e6e5a-d9fe-4edf-8d7c-52d2fa3c8817          Chaayos
# 107  ec4e6e5a-d9fe-4edf-8d7c-52d2fa3c8817          Chaayos
#
#            sku_category  quantity    gmv
# 0    Tea, Coffee & More       3.0  627.0
# 104  Tea, Coffee & More       5.0  695.0
# 105  Tea, Coffee & More       1.0  139.0
# 106  Tea, Coffee & More       1.0  139.0
# 107  Tea, Coffee & More       1.0  139.0

# %%
df_zepto.to_csv(f"{OUTPUT_DIR}/zepto_raw.csv", index=False)

# %% [markdown]
# ## 3. Instamart

# %%
df_instamart = pd.read_csv(f"{INPUT_DIR}/instamart-raw.csv", low_memory=False)

df_instamart.drop(df_instamart.iloc[:, 0:11], axis=1, inplace=True)

for col in df_instamart.select_dtypes(include="object"):
    df_instamart[col] = df_instamart[col].str.strip().astype("string")

df_instamart.rename(columns={"GMV.1": "GMV"}, inplace=True)
df_instamart["ORDERED_DATE"] = pd.to_datetime(df_instamart["ORDERED_DATE"], dayfirst=True, format="mixed")
df_instamart.sort_values("ORDERED_DATE", inplace=True)

# %%
df_instamart.info()
df_instamart.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82534 entries, 0 to 82533
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERED_DATE      82534 non-null  datetime64[ns]
#  1   CITY              82534 non-null  string
#  2   AREA_NAME         82534 non-null  string
#  3   STORE_ID          82534 non-null  int64
#  4   L1_CATEGORY       82534 non-null  string
#  5   L2_CATEGORY       82534 non-null  string
#  6   L3_CATEGORY       82534 non-null  string
#  7   PRODUCT_NAME      82534 non-null  string
#  8   VARIANT           82534 non-null  string
#  9   ITEM_CODE         82534 non-null  int64
#  10  COMBO             82534 non-null  string
#  11  COMBO_ITEM_CODE   4899 non-null   float64
#  12  COMBO_UNITS_SOLD  4899 non-null   float64
#  13  BASE_MRP          82534 non-null  int64
#  14  UNITS_SOLD        82534 non-null  int64
#  15  GMV               82534 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), string(8)
# memory usage: 10.7 MB
#     ORDERED_DATE    CITY    AREA_NAME  STORE_ID           L1_CATEGORY  \
# 0     2025-10-01    Agra  civil lines   1401076  tea, coffee and more
# 360   2025-10-01   Delhi  vasant kunj   1386536  tea, coffee and more
# 359   2025-10-01   Delhi  mayur vihar   1404576  tea, coffee and more
# 358   2025-10-01   Delhi  ashok vihar    816651  tea, coffee and more
# 357   2025-10-01  Bhopal     mp nagar   1399345  tea, coffee and more
#
#              L2_CATEGORY L3_CATEGORY  \
# 0                    tea  tea premix
# 360                  tea  tea premix
# 359  instant drink mixes     ice tea
# 358                  tea  tea premix
# 357                  tea  tea premix
#
#                                           PRODUCT_NAME    VARIANT  ITEM_CODE  \
# 0    chaayos instant tea premix - regular sugar - m...      330 g     399295
# 360  chaayos masala tea - premium chai patti with 1...      250 g     507889
# 359         chaayos instant peach iced tea premix(box)  10 pieces     115595
# 358  chaayos instant tea premix - regular sugar - c...      330 g     200836
# 357  chaayos instant tea premix - regular sugar - c...      330 g     200836
#
#     COMBO  COMBO_ITEM_CODE  COMBO_UNITS_SOLD  BASE_MRP  UNITS_SOLD  GMV
# 0     Yes         229392.0               1.0       168           1  168
# 360    No              NaN               NaN       299           2  598
# 359    No              NaN               NaN       119           2  238
# 358    No              NaN               NaN       189           3  567
# 357    No              NaN               NaN       189           2  378

# %%
df_instamart.to_csv(f"{OUTPUT_DIR}/instamart_raw.csv", index=False)

# %% [markdown]
# ## 4. FK Minutes

# %%
df_fkminutes = pd.read_csv(f"{INPUT_DIR}/fkminutes-raw.csv", low_memory=False)

df_fkminutes.drop(df_fkminutes.iloc[:, 0:11], axis=1, inplace=True)

for col in df_fkminutes.select_dtypes(include="object"):
    df_fkminutes[col] = df_fkminutes[col].str.strip().astype("string")

# Normalise date string and truncate to date part only
df_fkminutes["order_date_time"] = (
    df_fkminutes["order_date_time"]
    .str.replace("-", "/")
    .str[:10]
)
df_fkminutes["order_date_time"] = pd.to_datetime(df_fkminutes["order_date_time"], dayfirst=True, format="mixed")
df_fkminutes.sort_values("order_date_time", inplace=True)

# %%
df_fkminutes.info()
df_fkminutes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5958 entries, 0 to 5957
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_date_time          5958 non-null   datetime64[ns]
#  1   city                     5957 non-null   string
#  2   product_id               5958 non-null   string
#  3   analytic_business_unit   5958 non-null   string
#  4   analytic_super_category  5958 non-null   string
#  5   analytic_vertical        5958 non-null   string
#  6   brand_csv                5958 non-null   string
#  7   units                    5958 non-null   int64
#  8   mrp                      5958 non-null   int64
# dtypes: datetime64[ns](1), int64(2), string(6)
# memory usage: 465.5 KB
#    order_date_time       city        product_id analytic_business_unit  \
# 0       2025-10-01      Patna  TEAH35UHKB2DCZPV                    BGM
# 22      2025-10-01  Bangalore  TEAH35UP8DYXN3HJ                    BGM
# 21      2025-10-01    Kolkata  TEAH35UHKB2DCZPV                    BGM
# 20      2025-10-01      Delhi  TEAH35UPN3ZB4CPY                    BGM
# 18      2025-10-01     Mumbai  TEAH35UP8DYXN3HJ                    BGM
#
#    analytic_super_category analytic_vertical brand_csv  units   mrp
# 0         FoodAndNutrition               Tea   Chaayos      1   139
# 22        FoodAndNutrition               Tea   Chaayos      5   695
# 21        FoodAndNutrition               Tea   Chaayos      1   139
# 20        FoodAndNutrition               Tea   Chaayos      4  1396
# 18        FoodAndNutrition               Tea   Chaayos      3   417

# %%
df_fkminutes.to_csv(f"{OUTPUT_DIR}/fkminutes_raw.csv", index=False)

# %% [markdown]
# ## 5. Big Basket

# %%
df_bigbasket = pd.read_csv(f"{INPUT_DIR}/big-basket-raw.csv", low_memory=False)

df_bigbasket.drop(df_bigbasket.iloc[:, 0:10], axis=1, inplace=True)

for col in df_bigbasket.select_dtypes(include="object"):
    df_bigbasket[col] = df_bigbasket[col].str.strip().astype("string")

# Big Basket provides a date range string (YYYYMMDD) — split into start and end dates
df_bigbasket["start_date"] = pd.to_datetime(df_bigbasket["date_range"].str[:8],  format="%Y%m%d", errors="coerce")
df_bigbasket["end_date"]   = pd.to_datetime(df_bigbasket["date_range"].str[-8:], format="%Y%m%d", errors="coerce")

df_bigbasket = df_bigbasket[["start_date", "end_date", "date_range", "source_city_name", "brand_name",
                              "top_slug", "mid_slug", "leaf_slug", "source_sku_id", "sku_description",
                              "sku_weight", "total_quantity", "total_mrp", "total_sales"]]

# %%
df_bigbasket.info()
df_bigbasket.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   start_date        415 non-null    datetime64[ns]
#  1   end_date          415 non-null    datetime64[ns]
#  2   date_range        415 non-null    string
#  3   source_city_name  415 non-null    string
#  4   brand_name        415 non-null    string
#  5   top_slug          415 non-null    string
#  6   mid_slug          415 non-null    string
#  7   leaf_slug         415 non-null    string
#  8   source_sku_id     415 non-null    int64
#  9   sku_description   415 non-null    string
#  10  sku_weight        415 non-null    string
#  11  total_quantity    415 non-null    int64
#  12  total_mrp         415 non-null    int64
#  13  total_sales       415 non-null    float64
# dtypes: datetime64[ns](2), float64(1), int64(3), string(8)
# memory usage: 45.5 KB
#   start_date   end_date           date_range source_city_name brand_name  \
# 0 2025-10-01 2025-10-31  20251001 - 20251031        Bangalore    Chaayos
# 1 2025-10-01 2025-10-31  20251001 - 20251031          Gurgaon    Chaayos
# 2 2025-10-01 2025-10-31  20251001 - 20251031           Mumbai    Chaayos
# 3 2025-10-01 2025-10-31  20251001 - 20251031           Mumbai    Chaayos
# 4 2025-10-01 2025-10-31  20251001 - 20251031        Bangalore    Chaayos
#
#              top_slug            mid_slug                 leaf_slug  \
# 0  gourmet-world-food    drinks-beverages      gourmet-tea-tea-bags
# 1           beverages                 tea             leaf-dust-tea
# 2  gourmet-world-food    drinks-beverages      gourmet-tea-tea-bags
# 3           beverages  energy-soft-drinks  icetea-non-aerated-drink
# 4  gourmet-world-food    drinks-beverages      gourmet-tea-tea-bags
#
#    source_sku_id                                    sku_description  \
# 0       40194562        Chaayos instant-desi-masala-chai-tea 25 pcs
# 1       40348267                 Chaayos desi-masala-chai-tea 250 g
# 2       40348270  Chaayos instant-cardamom-tea-premix 210 g  (14...
# 3       40348265  Chaayos instant-lemon-iced-tea-premix 220 g  (...
# 4       40348271        Chaayos detox-kahwa-herbal-green-tea 25 pcs
#
#   sku_weight  total_quantity  total_mrp  total_sales
# 0     25 pcs              61      11539      9480.20
# 1      250 g               2        658       558.00
# 2      210 g               8       1512      1329.11
# 3      220 g              27       3213      2588.47
# 4     25 pcs              23       4807      3922.35

# %%
df_bigbasket.to_csv(f"{OUTPUT_DIR}/bigbasket_raw.csv", index=False)
